# %% [markdown]
# # DSCI511 Python Panda Review Session <Quiz 2>

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %% [markdown]
# ## 1. Dataframe VS Series

# %% [markdown]
# - **Dataframe is like a dictionary, but it is much more than a dictionary**
#     ```python
#     my_map = {“col0”: [row0_1, row0_2, row0_3],
#               “col1”: [row1_1, row1_2, row1_3],
#               “col2”: [row2_1, row2_2, row2_3],
#               “col3”: [row3_1, row3_2, row3_3]}
#     df = pd.DataFrame(my_map)
#     ```
#
#
# - **A Series is a column in the dataframe**
#     - A Series is like a NumPy array but with labels.
#     - 1-dimensional
#     - can contain any data type or a mix of them
#     - labels may be integers or strings
#     - ```python
#       pd.Series(place_holder)
#       ```
#      the placeholder can be any dtypes
#           - a scalar
#           - a list
#           - ndarray
#           - dictionary (then the Series has default index)
#           - object & string (USE MORE MEMORY)
# - **for series, use uniformed dtypes**

# %% [markdown]
# ## 2. DataFrame

# %%
# Create DataFrame from Lists of lists
df1 = pd.DataFrame([['Tom', 7], ['Mike', 15], ['Tiffany', 3]])


# Create DataFrame from ndarray
df2 = pd.DataFrame(np.array([['Tom',7], ['Mike', 15], ['Tiffany', 3]]))


# Create DataFrame from Dictionary
df3 = pd.DataFrame({"Name": ['Tom', 'Mike', 'Tiffany'], "Number": [7, 15, 3]})


# Create DataFrame from List of tuples
df4 = pd.DataFrame(zip(['Tom', 'Mike', 'Tiffany'], [7, 15, 3]))


# Create DataFrame from Series
df5 = pd.DataFrame({"Name": pd.Series(['Tom', 'Mike', 'Tiffany']), "Number": pd.Series([7, 15, 3])})

# %%
# load stackoverflow data
df = pd.read_csv('data/survey_results_public.csv')
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %% [markdown]
# ### 1) df attributes

# %%
df.shape
# df.info(verbose=True)
# df.columns
# df.head(2)
# Out:
# (64461, 61)

# %%
# df to markdown table
# df1 = pd.DataFrame([[1, 2, 3], [4, 5, 6], [7, 8, 9]])
# df1.to_markdown()

# %% [markdown]
# ### 2) df operations
#
# [Link](https://pandas.pydata.org/pandas-docs/stable/reference/frame.html)

# %%
# get the max value for each numerical column
df.max()


# get the mean value for a specific numerical column
df['Age'].mean()


# get the row number for a specific numerical column
# df['Age'].idxmin()


# get the sum value for each numerical column
# df.sum()


# get the mean value for each numerical column
# df.mean()


# sort the dataframe according to something
# df.sort_values(by='Age', ascending=False)


# count Categorical values in a row
# df.columns
df['Sexuality'].value_counts()
# df['Hobbyist'].value_counts()['Yes']/df.shape[0]
# Out:
# Straight / Heterosexual                                  40118
# Bisexual                                                  1918
# Gay or Lesbian                                             978
# Bisexual;Straight / Heterosexual                           258
# Queer                                                      249
# Bisexual;Queer                                             191
# Gay or Lesbian;Queer                                        90
# Straight / Heterosexual;Queer                               56
# Bisexual;Gay or Lesbian                                     40
# Bisexual;Gay or Lesbian;Straight / Heterosexual;Queer       39
# Bisexual;Gay or Lesbian;Queer                               24
# Gay or Lesbian;Straight / Heterosexual                      13
# Bisexual;Straight / Heterosexual;Queer                      10
# Bisexual;Gay or Lesbian;Straight / Heterosexual              8
# Name: Sexuality, dtype: int64

# %% [markdown]
# ### 2) df indexing
# how powerful **pandas** is!!

# %%
# ------------------------------------------------ df[] --------------------------------------------
# Select column - get a Series
df["Country"]

# Select row slice - get a DataFrame with all cols
df[20000:20010]

# Select by boolean - DataFrame, series - all possible
df[df['Age'] > 50]



# ---------------------------------- df.loc[row_label(s), col_label(s)] -----------------------------
# Select row/column by label
df.loc[:, 'Age':'Country']
df.loc[[20006, 60000], ['CompTotal', 'Country']]


# Select by row integer & column label
df.loc[df.index[20006], ['CompTotal', 'Country', 'EdLevel', 'Age', 'LanguageWorkedWith']]



# ---------------------------------- df.iloc[row_int(s), col_int(s)] -----------------------------
# Select row/column by integer
df.iloc[20006, 20]



# ---------------------------------- mix type -----------------------------
# Select by row integer & column label - df.loc[df.index[row_int], col_label]
df.loc[df.index[20006], 'Country']

# Select by row label & column integer - df.loc[20006, df.columns[20]]
df.loc[20006, df.columns[5]]


# ---------------------------------- Select by boolean expression -----------------------------
salary_threshold = 200000
df.query("CompTotal > @salary_threshold")
# Out:
#        Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 43             44  I am a developer by profession       No  32.0         21
# 66             67  I am a developer by profession      Yes  35.0          6
# 68             69  I am a developer by profession      Yes  25.0         12
# 89             91  I am a developer by profession      Yes  28.0         25
# 136           138  I am a developer by profession      Yes  25.0         18
# ...           ...                             ...      ...   ...        ...
# 64121       65595  I am a developer by profession      Yes   NaN         20
# 64125       65600  I am a developer by profession       No   NaN          6
# 64148       65625  I am a developer by profession      Yes   NaN         17
# 64153       65630  I am a developer by profession      Yes   NaN         17
# 64154       65631  I am a developer by profession      Yes   NaN         13
#
#       CompFreq   CompTotal  ConvertedComp  \
# 43      Yearly    244000.0        55893.0
# 66      Yearly    250000.0       250000.0
# 68      Yearly    550000.0       594539.0
# 89     Monthly  70000000.0        61476.0
# 136     Yearly    215000.0       215000.0
# ...        ...         ...            ...
# 64121   Yearly  27170564.0          369.0
# 64125  Monthly   1000000.0        38484.0
# 64148  Monthly   5500000.0        19428.0
# 64153  Monthly   1000000.0        15048.0
# 64154   Yearly   4310000.0        38759.0
#
#                                     Country          CurrencyDesc  \
# 43                                   Brazil        Brazilian real
# 66                            United States  United States dollar
# 68                                   France         European Euro
# 89                                Indonesia     Indonesian rupiah
# 136                           United States  United States dollar
# ...                                     ...                   ...
# 64121  Venezuela, Bolivarian Republic of...    Venezuelan bolivar
# 64125                               Hungary      Hungarian forint
# 64148                              Colombia        Colombian peso
# 64153                                 Chile          Chilean peso
# 64154                                 Japan          Japanese yen
#
#       CurrencySymbol                             DatabaseDesireNextYear  \
# 43               BRL                               Microsoft SQL Server
# 66               USD                                   PostgreSQL;Redis
# 68               EUR                                         PostgreSQL
# 89               IDR                                         PostgreSQL
# 136              USD                                                NaN
# ...              ...                                                ...
# 64121            VES  Firebase;MariaDB;Microsoft SQL Server;MongoDB;...
# 64125            HUF                                                NaN
# 64148            COP                                                NaN
# 64153            CLP                                                NaN
# 64154            JPY                                                NaN
#
#                         DatabaseWorkedWith  \
# 43                    Microsoft SQL Server
# 66               Firebase;PostgreSQL;Redis
# 68                                 MongoDB
# 89                              PostgreSQL
# 136    DynamoDB;Microsoft SQL Server;MySQL
# ...                                    ...
# 64121                        MariaDB;MySQL
# 64125                                  NaN
# 64148                                  NaN
# 64153                                  NaN
# 64154                                  NaN
#
#                                                  DevType  \
# 43     Data or business analyst;Developer, back-end;P...
# 66     Developer, full-stack;Product manager;Senior e...
# 68     Data scientist or machine learning specialist;...
# 89                                              Designer
# 136    Database administrator;Designer;Developer, bac...
# ...                                                  ...
# 64121  Database administrator;Developer, back-end;Dev...
# 64125  Data or business analyst;Developer, desktop or...
# 64148                              Developer, QA or test
# 64153  Developer, full-stack;Developer, QA or test;Sy...
# 64154                               Developer, front-end
#
#                                                  EdLevel  \
# 43       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 66                    Professional degree (JD, MD, etc.)
# 68       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 89     Some college/university study without earning ...
# 136         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                  ...
# 64121  Some college/university study without earning ...
# 64125    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 64148       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 64153       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 64154       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                               Employment  \
# 43                                    Employed full-time
# 66                                    Employed full-time
# 68                                    Employed full-time
# 89                                    Employed full-time
# 136                                   Employed full-time
# ...                                                  ...
# 64121                                 Employed full-time
# 64125  Independent contractor, freelancer, or self-em...
# 64148                                 Employed full-time
# 64153                                 Employed full-time
# 64154                                 Employed full-time
#
#                           Ethnicity Gender  \
# 43     White or of European descent    Man
# 66     White or of European descent    Man
# 68     White or of European descent    Man
# 89                              NaN    Man
# 136                 Southeast Asian    Man
# ...                             ...    ...
# 64121                           NaN    NaN
# 64125                           NaN    NaN
# 64148                           NaN    NaN
# 64153                           NaN    NaN
# 64154                           NaN    NaN
#
#                                               JobFactors  \
# 43     Industry that I’d be working in;Specific depar...
# 66     Languages, frameworks, and other technologies ...
# 68     Flex time or a flexible schedule;How widely us...
# 89     Flex time or a flexible schedule;Languages, fr...
# 136    Flex time or a flexible schedule;How widely us...
# ...                                                  ...
# 64121                                                NaN
# 64125                                                NaN
# 64148  Industry that I’d be working in;Languages, fra...
# 64153  Languages, frameworks, and other technologies ...
# 64154                                                NaN
#
#                                    JobSat  \
# 43     Neither satisfied nor dissatisfied
# 66                         Very satisfied
# 68                         Very satisfied
# 89                         Very satisfied
# 136                    Slightly satisfied
# ...                                   ...
# 64121                   Very dissatisfied
# 64125                      Very satisfied
# 64148                  Slightly satisfied
# 64153  Neither satisfied nor dissatisfied
# 64154  Neither satisfied nor dissatisfied
#
#                                                  JobSeek  \
# 43     I’m not actively looking, but I am open to new...
# 66          I am not interested in new job opportunities
# 68          I am not interested in new job opportunities
# 89          I am not interested in new job opportunities
# 136    I’m not actively looking, but I am open to new...
# ...                                                  ...
# 64121                                                NaN
# 64125                                                NaN
# 64148       I am not interested in new job opportunities
# 64153  I’m not actively looking, but I am open to new...
# 64154                                                NaN
#
#                                   LanguageDesireNextYear  \
# 43                 HTML/CSS;Java;JavaScript;Python;R;SQL
# 66                                                  Rust
# 68                                 Python;Rust;Scala;SQL
# 89                   HTML/CSS;JavaScript;Ruby;TypeScript
# 136                                                 Dart
# ...                                                  ...
# 64121  Bash/Shell/PowerShell;C#;C++;HTML/CSS;JavaScri...
# 64125                                                NaN
# 64148                                                NaN
# 64153                                                NaN
# 64154                                                NaN
#
#                                       LanguageWorkedWith  \
# 43                             HTML/CSS;Python;R;SQL;VBA
# 66                              HTML/CSS;JavaScript;Ruby
# 68                                       HTML/CSS;Python
# 89                   HTML/CSS;JavaScript;Ruby;TypeScript
# 136    Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# ...                                                  ...
# 64121  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 64125                                                NaN
# 64148                                                NaN
# 64153                                                NaN
# 64154                                                NaN
#
#                        MiscTechDesireNextYear           MiscTechWorkedWith  \
# 43                                        NaN                          NaN
# 66                                        NaN                          NaN
# 68                    Keras;Pandas;TensorFlow      Keras;Pandas;TensorFlow
# 89                                        NaN                          NaN
# 136                                  Unity 3D  .NET;.NET Core;React Native
# ...                                       ...                          ...
# 64121  .NET;.NET Core;Cordova;Node.js;Xamarin                          NaN
# 64125                                     NaN                          NaN
# 64148                                     NaN                          NaN
# 64153                                     NaN                          NaN
# 64154                                     NaN                          NaN
#
#                             NEWCollabToolsDesireNextYear  \
# 43                                   Github;Slack;Trello
# 66           Github;Slack;Google Suite (Docs, Meet, etc)
# 68           Github;Slack;Google Suite (Docs, Meet, etc)
# 89                                                   NaN
# 136                                                  NaN
# ...                                                  ...
# 64121  Github;Gitlab;Slack;Trello;Google Suite (Docs,...
# 64125                                                NaN
# 64148                                                NaN
# 64153                                                NaN
# 64154                                                NaN
#
#                                 NEWCollabToolsWorkedWith NEWDevOps  \
# 43                                   Github;Slack;Trello        No
# 66     Github;Gitlab;Slack;Trello;Google Suite (Docs,...        No
# 68     Confluence;Jira;Github;Slack;Google Suite (Doc...       Yes
# 89                                                   NaN       Yes
# 136                         Slack;Microsoft Azure;Trello        No
# ...                                                  ...       ...
# 64121                                      Github;Gitlab        No
# 64125                                                NaN        No
# 64148                                                NaN  Not sure
# 64153                                                NaN       Yes
# 64154                                                NaN        No
#
#              NEWDevOpsImpt                           NEWEdImpt  \
# 43      Somewhat important                      Very important
# 66     Extremely important                    Fairly important
# 68     Extremely important                      Very important
# 89     Extremely important  Not at all important/not necessary
# 136    Extremely important                    Fairly important
# ...                    ...                                 ...
# 64121  Extremely important                      Very important
# 64125              Neutral                  Somewhat important
# 64148   Somewhat important                    Fairly important
# 64153              Neutral                      Very important
# 64154                  NaN                    Fairly important
#
#                                               NEWJobHunt  \
# 43     Having a bad day (or week or month) at work;Cu...
# 66     Curious about other opportunities;Trouble with...
# 68     Curious about other opportunities;Better compe...
# 89                                                   NaN
# 136    Curious about other opportunities;Better compe...
# ...                                                  ...
# 64121                                                NaN
# 64125                                                NaN
# 64148  Having a bad day (or week or month) at work;Cu...
# 64153  Curious about other opportunities;Better compe...
# 64154                                                NaN
#
#                                       NEWJobHuntResearch  \
# 43     Company reviews from third party sites (e.g. G...
# 66     Read company media, such as employee blogs or ...
# 68     Read company media, such as employee blogs or ...
# 89                                                   NaN
# 136    Read company media, such as employee blogs or ...
# ...                                                  ...
# 64121                                                NaN
# 64125                                                NaN
# 64148  Company reviews from third party sites (e.g. G...
# 64153  Company reviews from third party sites (e.g. G...
# 64154                                                NaN
#
#                    NEWLearn NEWOffTopic                NEWOnboardGood  \
# 43     Once every few years          No                            No
# 66              Once a year         NaN  Onboarding? What onboarding?
# 68              Once a year          No                            No
# 89         Every few months          No                           Yes
# 136        Every few months          No                           Yes
# ...                     ...         ...                           ...
# 64121  Once every few years          No  Onboarding? What onboarding?
# 64125                   NaN         NaN  Onboarding? What onboarding?
# 64148                   NaN         NaN                           Yes
# 64153                   NaN         NaN                            No
# 64154                   NaN         NaN                           Yes
#
#       NEWOtherComms                                        NEWOvertime  \
# 43               No                   Often: 1-2 days per week or more
# 66               No                  Rarely: 1-2 days per year or less
# 68               No  Sometimes: 1-2 days per month but less than we...
# 89               No                   Often: 1-2 days per week or more
# 136              No                                              Never
# ...             ...                                                ...
# 64121           Yes                   Often: 1-2 days per week or more
# 64125           NaN                                              Never
# 64148           NaN                  Rarely: 1-2 days per year or less
# 64153           Yes  Sometimes: 1-2 days per month but less than we...
# 64154           NaN                  Rarely: 1-2 days per year or less
#
#                                      NEWPurchaseResearch      NEWPurpleLink  \
# 43     Start a free trial;Ask developers I know/work ...  Hello, old friend
# 66     Start a free trial;Ask developers I know/work ...            Annoyed
# 68     Ask developers I know/work with;Visit develope...  Hello, old friend
# 89                                    Start a free trial  Hello, old friend
# 136                                                  NaN  Hello, old friend
# ...                                                  ...                ...
# 64121  Start a free trial;Ask developers I know/work ...  Hello, old friend
# 64125                                                NaN                NaN
# 64148                                                NaN                NaN
# 64153                                                NaN                NaN
# 64154                                                NaN                NaN
#
#                                               NEWSOSites  \
# 43     Stack Overflow (public Q&A for anyone who code...
# 66                                                   NaN
# 68     Stack Overflow (public Q&A for anyone who code...
# 89      Stack Overflow (public Q&A for anyone who codes)
# 136    Stack Overflow (public Q&A for anyone who code...
# ...                                                  ...
# 64121  Stack Overflow (public Q&A for anyone who code...
# 64125                                                NaN
# 64148                                                NaN
# 64153   Stack Overflow (public Q&A for anyone who codes)
# 64154                                                NaN
#
#                                                 NEWStuck        OpSys  \
# 43     Call a coworker or friend;Visit Stack Overflow...      Windows
# 66     Call a coworker or friend;Go for a walk or oth...  Linux-based
# 68     Call a coworker or friend;Visit Stack Overflow...        MacOS
# 89     Visit Stack Overflow;Do other work and come ba...  Linux-based
# 136    Play games;Visit Stack Overflow;Go for a walk ...        MacOS
# ...                                                  ...          ...
# 64121  Play games;Call a coworker or friend;Visit Sta...  Linux-based
# 64125                                                NaN          NaN
# 64148                                                NaN          NaN
# 64153                                                NaN          NaN
# 64154                                                NaN          NaN
#
#                                                  OrgSize  \
# 43                                    10 to 19 employees
# 66                                      2 to 9 employees
# 68                                    20 to 99 employees
# 89                                    20 to 99 employees
# 136                             10,000 or more employees
# ...                                                  ...
# 64121                           1,000 to 4,999 employees
# 64125  Just me - I am a freelancer, sole proprietor, ...
# 64148                               500 to 999 employees
# 64153                                   2 to 9 employees
# 64154                                 20 to 99 employees
#
#                                   PlatformDesireNextYear  \
# 43                                         Linux;Windows
# 66                          Docker;Google Cloud Platform
# 68                                      Kubernetes;Linux
# 89                       Android;iOS;Linux;MacOS;Windows
# 136                                                  NaN
# ...                                                  ...
# 64121  Android;AWS;Docker;Google Cloud Platform;Herok...
# 64125                                                NaN
# 64148                                                NaN
# 64153                                                NaN
# 64154                                                NaN
#
#                                       PlatformWorkedWith  \
# 43                                               Windows
# 66     Docker;Google Cloud Platform;Heroku;Kubernetes...
# 68                                 Linux;Microsoft Azure
# 89                       Android;iOS;Linux;MacOS;Windows
# 136           Android;Docker;iOS;Microsoft Azure;Windows
# ...                                                  ...
# 64121                                      Linux;Windows
# 64125                                                NaN
# 64148                                                NaN
# 64153                                                NaN
# 64154                                                NaN
#
#                            PurchaseWhat                Sexuality SOAccount  \
# 43                I have some influence  Straight / Heterosexual       Yes
# 66     I have a great deal of influence  Straight / Heterosexual       NaN
# 68                I have some influence                 Bisexual       Yes
# 89                I have some influence  Straight / Heterosexual       Yes
# 136       I have little or no influence  Straight / Heterosexual        No
# ...                                 ...                      ...       ...
# 64121             I have some influence                      NaN       Yes
# 64125                               NaN                      NaN       NaN
# 64148                               NaN                      NaN       NaN
# 64153                               NaN                      NaN        No
# 64154                               NaN                      NaN       NaN
#
#                 SOComm                                         SOPartFreq  \
# 43       Yes, somewhat                    A few times per month or weekly
# 66                 NaN                                                NaN
# 68       Yes, somewhat                    A few times per month or weekly
# 89     Yes, definitely                             Multiple times per day
# 136     No, not at all                                                NaN
# ...                ...                                                ...
# 64121  Yes, definitely  I have never participated in Q&A on Stack Over...
# 64125              NaN                                                NaN
# 64148              NaN                                                NaN
# 64153          Neutral                                                NaN
# 64154              NaN                                                NaN
#
#                   SOVisitFreq                  SurveyEase  \
# 43     Multiple times per day  Neither easy nor difficult
# 66                        NaN                        Easy
# 68       A few times per week                        Easy
# 89     Multiple times per day                        Easy
# 136    Multiple times per day                        Easy
# ...                       ...                         ...
# 64121  Multiple times per day                         NaN
# 64125                     NaN                         NaN
# 64148                     NaN                         NaN
# 64153    A few times per week                         NaN
# 64154                     NaN                         NaN
#
#                 SurveyLength Trans  \
# 43     Appropriate in length    No
# 66     Appropriate in length    No
# 68                 Too short    No
# 89                  Too long    No
# 136    Appropriate in length    No
# ...                      ...   ...
# 64121                    NaN   NaN
# 64125                    NaN   NaN
# 64148                    NaN   NaN
# 64153                    NaN   NaN
# 64154                    NaN   NaN
#
#                                           UndergradMajor  \
# 43     Another engineering discipline (such as civil,...
# 66     Another engineering discipline (such as civil,...
# 68     Computer science, computer engineering, or sof...
# 89     A health science (such as nursing, pharmacy, r...
# 136    Information systems, information technology, o...
# ...                                                  ...
# 64121  Computer science, computer engineering, or sof...
# 64125  A humanities discipline (such as literature, h...
# 64148  Computer science, computer engineering, or sof...
# 64153  Information systems, information technology, o...
# 64154                      Web development or web design
#
#                                  WebframeDesireNextYear  \
# 43                                                  NaN
# 66                                             React.js
# 68                                         Django;Flask
# 89                                        Ruby on Rails
# 136                                                 NaN
# ...                                                 ...
# 64121  Angular.js;Django;jQuery;Laravel;React.js;Vue.js
# 64125                                               NaN
# 64148                                               NaN
# 64153                                               NaN
# 64154                                               NaN
#
#                                       WebframeWorkedWith  \
# 43                                                   NaN
# 66                                         Ruby on Rails
# 68                                          Django;Flask
# 89                                  jQuery;Ruby on Rails
# 136    Angular;Angular.js;ASP.NET;ASP.NET Core;jQuery...
# ...                                                  ...
# 64121                              jQuery;Laravel;Vue.js
# 64125                                                NaN
# 64148                                                NaN
# 64153                                                NaN
# 64154                                                NaN
#
#                                            WelcomeChange  WorkWeekHrs  \
# 43               Just as welcome now as I felt last year         45.0
# 66                                                   NaN         40.0
# 68               Just as welcome now as I felt last year         40.0
# 89     Not applicable - I did not use Stack Overflow ...         60.0
# 136              Just as welcome now as I felt last year         60.0
# ...                                                  ...          ...
# 64121              A lot more welcome now than last year         63.0
# 64125                                                NaN         20.0
# 64148                                                NaN         40.0
# 64153                                                NaN         45.0
# 64154                                                NaN         40.0
#
#       YearsCode      YearsCodePro
# 43           10                 6
# 66           30                15
# 68           13                 3
# 89            3                 2
# 136           4                 2
# ...         ...               ...
# 64121        29                27
# 64125        30                12
# 64148        12                 5
# 64153         7                 3
# 64154         5  Less than 1 year
#
# [4867 rows x 61 columns]

# %% [markdown]
# ### 2) set df index
# a nice unique identifier for a row

# %%
# approach 1:
# df.set_index("Respondent", inplace=True)
# schema_df.set_index('Column', inplace=True)

# approach 2:
# df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')

# %%
# df.head(10)


# after set index, we can use `loc`
# schema_df.loc['Respondent', 'QuestionText']
# schema_df.loc[1] # we cannot do this anymore
# sort index
# schema_df.sort_index(ascending=False)

# schema_df.head(10)

# %% [markdown]
# ## 3. series

# %% [markdown]
# #### 1) basic series

# %%
# -------------------------------- create our own series --------------------------
s = pd.Series(data = [2, 4, 6, 8, 10], index = ['Apple', 'Banana', 'Cherries', 'Dragon Fruit', 'Mango'], name = "A Column")
s

# rename
s.rename("another_name")

# access the data using numpy
# s.to_numpy()

# check elements type
# print(f"the type of elements in s:\n {s.map(type)}")
print(f"s dtype: {s.dtype}")

# check memory usage
print(f"s memory usage: {s.memory_usage(deep=True)} bytes")
# Out:
# s dtype: int64
# s memory usage: 361 bytes

# %% [markdown]
# #### 2) series indexing

# %%
# 1. number indexing
s[[1, 2, 3]]
s[0:3]



# 2. key indexing
s["Apple"]
s[['Apple', 'Banana', 'Cherries', 'Dragon Fruit', 'Mango']]



# 3. boolean indexing with series
s[s > s.mean()]
# Out:
# Dragon Fruit     8
# Mango           10
# Name: A Column, dtype: int64

# %% [markdown]
# #### 3) series operations
#
# [Doc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html)

# %%
# for two series, the operations are done based on labels/indexes
s1 = pd.Series(data = range(4), index = ["A", "B", "C", "D"])
s2 = pd.Series(data = range(10, 14), index = ["B", "C", "D", "E"])

s1 + s2

# for a single series
s1 ** 2
np.exp(s1)
s1.mean()
s1.sum()
s1.astype("float")
s1.add(3.141).pow(2).mean() #piping

# print all common methods
# print([_ for _ in dir(pd.Series) if not _.startswith("_")])
# Out:
# 22.788881
